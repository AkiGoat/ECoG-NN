# %%
import random
import os.path
import gzip
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline
import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torchvision import transforms
import pandas as pd
import numpy as np
import os

# %%
dataset_dir = 'data/Origin/withoutICA/ECoGICA_'
# freq_list = [700,800,900,1000,1100,1200,1300,1400,1500,1600]
data_file = dataset_dir + '700.txt'
# with open(data_file, 'rb') as f:
#     dataset = pickle.load(f)
column_list=[]
for i in range(1, 12501):
    column_list.append(i)
# print(column_list)
data_np=pd.read_csv(data_file, sep='\t', header=None).loc[1: , column_list].to_numpy()
# print(data_np)
# print(np.size(data_np, 0))
# print(np.size(data_np, 1))
data_np_sp = data_np.reshape(100, 96, 125)
# print(np.size(data_np_sp, 0))
# print(np.size(data_np_sp, 1))
# print(np.size(data_np_sp, 2))
print(np.size(data_np_sp[0], 1))
# Out:
# 125

# %%
sample = [dataset[1600][:][:]]
print(sample)
# Out:
# [array([[[0.64698887, 0.63975143, 0.61735618, ..., 0.54892021,
#          0.478394  , 0.43333954],
#         [0.45573276, 0.53332424, 0.62616044, ..., 0.55853242,
#          0.49098092, 0.43051234],
#         [0.44099727, 0.47541735, 0.48649982, ..., 0.41775909,
#          0.51741046, 0.57283688],
#         ...,
#         [0.71191716, 0.67988998, 0.65473276, ..., 0.56612909,
#          0.56696808, 0.58786875],
#         [0.62411284, 0.67374861, 0.70050395, ..., 0.55774534,
#          0.58238161, 0.60871708],
#         [0.57769668, 0.53650641, 0.53619444, ..., 0.52498883,
#          0.50866228, 0.50045288]],
#
#        [[0.6098243 , 0.61713678, 0.59907216, ..., 0.48297167,
#          0.42869091, 0.3907299 ],
#         [0.41290238, 0.49110931, 0.58006805, ..., 0.51563925,
#          0.48893896, 0.44886354],
#         [0.4319213 , 0.43331414, 0.43458369, ..., 0.36676794,
#          0.424292  , 0.48401341],
#         ...,
#         [0.76543224, 0.72050297, 0.66529828, ..., 0.48691022,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-0787039b93cb> in <module>
# ----> 1 tmp = sample[0].reshape(96,100,125)
#
# AttributeError: 'dict' object has no attribute 'reshape'
